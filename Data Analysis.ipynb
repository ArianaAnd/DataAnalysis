# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Citire date

# %%
df = pd.read_csv('airbnb_dates.csv', sep=';')
df.head()
# Out:
#                                            listings  \
# 0          FUNTASTICHostel in the Centre: Bed Stage
# 1  ROOM 88 Unique Experience Location and Lightning
# 2            2 Bedroom Spacious & Modern Apartament
# 3                             4-5 guests apartament
# 4                             5 Stars luxury Studio
#
#                                                  url     guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...  10 guests  1 bedroom
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...   4 guests  1 bedroom
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...   4 guests  2 bedroom
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...   4 guests  2 bedroom
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...   2 guests     studio
#
#      bed bathrooms                     room_type  price host_name  reviews  \
# 0  1 bed    1 bath  Shared room in the apartment   81.0    George       18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 14 columns):
# listings     268 non-null object
# url          268 non-null object
# guests       268 non-null object
# bedrooms     268 non-null object
# bed          268 non-null object
# bathrooms    268 non-null object
# room_type    268 non-null object
# price        268 non-null float64
# host_name    268 non-null object
# reviews      268 non-null int64
# stars        258 non-null float64
# location     268 non-null object
# latitude     268 non-null int64
# longitude    268 non-null int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 29.4+ KB

# %%
df.index.name = 'Id'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=268, step=1, name='Id')

# %%
df.values
# Out:
# array([['FUNTASTICHostel in the Centre: Bed Stage',
#         'https://www.airbnb.com.ro/rooms/37103158?location=Brasov%2C%20Bra%C8%99ov%2C%20Ruman%C3%ADa&check_in=2020-07-04&check_out=2020-07-05&source_impression_id=p3_1588160730_t4mVWMsfewgBpYu2&guests=1&adults=1',
#         '10 guests', ..., 'Brasov, Romania', 4564293, 2559111],
#        ['ROOM 88 Unique Experience Location and Lightning',
#         'https://www.airbnb.com.ro/rooms/39272931?location=Brasov%2C%20Bra%C8%99ov%2C%20Ruman%C3%ADa&check_in=2020-07-04&check_out=2020-07-05&source_impression_id=p3_1588066417_hwND5Qtw3pn7PA0c&guests=1&adults=1',
#         '4 guests', ..., 'Brasov, Romania', 4563993, 2559325],
#        ['2 Bedroom Spacious & Modern Apartament',
#         'https://www.airbnb.com.ro/rooms/39502159?location=Brasov%2C%20Bra%C8%99ov%2C%20Ruman%C3%ADa&check_in=2020-07-04&check_out=2020-07-05&previous_page_section_name=1000&federated_search_id=70821c51-f637-401b-94c8-ae36ca600b71',
# ...

# %%
df.head()
# Out:
#                                             listings  \
# Id
# 0           FUNTASTICHostel in the Centre: Bed Stage
# 1   ROOM 88 Unique Experience Location and Lightning
# 2             2 Bedroom Spacious & Modern Apartament
# 3                              4-5 guests apartament
# 4                              5 Stars luxury Studio
#
#                                                   url     guests   bedrooms  \
# Id
# 0   https://www.airbnb.com.ro/rooms/37103158?locat...  10 guests  1 bedroom
# 1   https://www.airbnb.com.ro/rooms/39272931?locat...   4 guests  1 bedroom
# 2   https://www.airbnb.com.ro/rooms/39502159?locat...   4 guests  2 bedroom
# 3   https://www.airbnb.com.ro/rooms/30854683?locat...   4 guests  2 bedroom
# 4   https://www.airbnb.com.ro/rooms/40392854?locat...   2 guests     studio
#
#       bed bathrooms                     room_type  price host_name  reviews  \
# Id
# 0   1 bed    1 bath  Shared room in the apartment   81.0    George       18
# ...

# %% [markdown]
# # Compunere date

# %%
# dataframe elements
df.size
# Out:
# 3752

# %%
# dataframe dimensions
df.ndim
# Out:
# 2

# %%
# dataframe shape
df.shape
# Out:
# (268, 14)

# %%
# traspose dataframe
df.T
# Out:
# Id                                                       0    \
# listings            FUNTASTICHostel in the Centre: Bed Stage
# url        https://www.airbnb.com.ro/rooms/37103158?locat...
# guests                                             10 guests
# bedrooms                                           1 bedroom
# bed                                                    1 bed
# bathrooms                                             1 bath
# room_type                       Shared room in the apartment
# price                                                     81
# host_name                                             George
# reviews                                                   18
# stars                                                   4.67
# location                                     Brasov, Romania
# latitude                                             4564293
# longitude                                            2559111
#
# ...

# %% [markdown]
# # Pandas data types

# %%
df.columns
# Out:
# Index(['listings', 'url', 'guests', 'bedrooms', 'bed', 'bathrooms',
#        'room_type', 'price', 'host_name', 'reviews', 'stars', 'location',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
df['listings'] = df['url'].astype('category')
df['listings'] = df['url'].astype('category')
df.dtypes
# Out:
# listings     category
# url            object
# guests         object
# bedrooms       object
# bed            object
# bathrooms      object
# room_type      object
# price         float64
# host_name      object
# reviews         int64
# stars         float64
# location       object
# latitude        int64
# longitude       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 14 columns):
# listings     268 non-null category
# url          268 non-null object
# guests       268 non-null object
# bedrooms     268 non-null object
# bed          268 non-null object
# bathrooms    268 non-null object
# room_type    268 non-null object
# price        268 non-null float64
# host_name    268 non-null object
# reviews      268 non-null int64
# stars        258 non-null float64
# location     268 non-null object
# latitude     268 non-null int64
# longitude    268 non-null int64
# dtypes: category(1), float64(2), int64(3), object(8)
# memory usage: 39.8+ KB

# %%
df['listings'].value_counts()
# Out:
# https://www.airbnb.com.ro/s/Brasov--Bra%C8%99ov--Ruman%C3%ADa/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&place_id=ChIJ8RSiKoZbs0ARDx45VO_y9Ww&source=structured_search_input_header&search_type=pagination&map_toggle=false&federated_search_session_id=cb4d30c4-6148-4462-8466-8ad91ab3200a&section_offset=3&items_offset=160&query=Bra%C8%99ov%2C%20Rom%C3%A2nia&checkin=2020-07-04&checkout=2020-07-05    3
# https://www.airbnb.com.ro/rooms/41906045?location=Brasov%2C%20Bra%C8%99ov%2C%20Ruman%C3%ADa&check_in=2020-07-04&check_out=2020-07-05&source_impression_id=p3_1588237194_WJL6GOLmUbKWq%2Bk0&guests=1&adults=1                                                                                                                                                                                                            3
# ...

# %% [markdown]
# # Indexing and selection

# %%
df.tail()
# Out:
#                                               listings  \
# Id
# 263  https://www.airbnb.com.ro/rooms/42726300?locat...
# 264  https://www.airbnb.com.ro/rooms/41489971?locat...
# 265  https://www.airbnb.com.ro/rooms/41105469?locat...
# 266  https://www.airbnb.com.ro/rooms/41105712?locat...
# 267  https://www.airbnb.com.ro/rooms/36500195?locat...
#
#                                                    url    guests    bedrooms  \
# Id
# 263  https://www.airbnb.com.ro/rooms/42726300?locat...  6 guests  2 bedrooms
# 264  https://www.airbnb.com.ro/rooms/41489971?locat...  4 guests   1 bedroom
# 265  https://www.airbnb.com.ro/rooms/41105469?locat...  2 guests   1 bedroom
# 266  https://www.airbnb.com.ro/rooms/41105712?locat...  2 guests   1 bedroom
# 267  https://www.airbnb.com.ro/rooms/36500195?locat...  4 guests   1 bedroom
#
#         bed bathrooms                   room_type  price host_name  reviews  \
# Id
# 263   0 bed    2 bath                 Entire home  439.0    Vartej        1
# ...

# %%
df['price'].head()
# Out:
# Id
# 0     81.0
# 1    215.0
# 2    140.0
# 3    121.0
# 4    131.0
# Name: price, dtype: float64

# %%
df['bedrooms'].head()
# Out:
# Id
# 0    1 bedroom
# 1    1 bedroom
# 2    2 bedroom
# 3    2 bedroom
# 4       studio
# Name: bedrooms, dtype: object

# %%
csv2 = pd.read_csv("airbnb_datesv2.csv", sep=';')
pattern = '*2 bedroom'
print(len(pattern))
# Out:
# 10

# %%
csv2 = pd.read_csv("airbnb_datesv2.csv", sep=';')
pattern = '*1 bedrooms'
print(len(pattern))
# Out:
# 11

# %%
csv2 = pd.read_csv("airbnb_datesv2.csv", sep=';')
pattern = '*3 bedroom'
print(len(pattern))
# Out:
# 10

# %%
csv2 = pd.read_csv("airbnb_datesv2.csv", sep=';')
pattern = '100 bedroom'
print(len(pattern))
# Out:
# 11

# %%
df['stars'].head()
# Out:
# Id
# 0    4.67
# 1    4.91
# 2    5.00
# 3    0.00
# 4    4.83
# Name: stars, dtype: float64

# %%
df['host_name'].head()
# Out:
# Id
# 0    George
# 1     Tudor
# 2     Costi
# 3      Nicu
# 4    Marius
# Name: host_name, dtype: object

# %%
df.loc[3]
# Out:
# listings     https://www.airbnb.com.ro/rooms/30854683?locat...
# url          https://www.airbnb.com.ro/rooms/30854683?locat...
# guests                                                4 guests
# bedrooms                                             2 bedroom
# bed                                                      2 bed
# bathrooms                                               1 bath
# room_type                                          Entire home
# price                                                      121
# host_name                                                 Nicu
# reviews                                                      0
# stars                                                        0
# location                                       Brasov, Romania
# latitude                                               4564067
# longitude                                            256102754
# Name: 3, dtype: object

# %%
df.loc[3: 10]
# Out:
#                                              listings  \
# Id
# 3   https://www.airbnb.com.ro/rooms/30854683?locat...
# 4   https://www.airbnb.com.ro/rooms/40392854?locat...
# 5   https://www.airbnb.com.ro/rooms/39247207?locat...
# 6   https://www.airbnb.com.ro/rooms/37375840?locat...
# 7   https://www.airbnb.com.ro/rooms/37008313?locat...
# 8   https://www.airbnb.com.ro/rooms/37516728?locat...
# 9   https://www.airbnb.com/rooms/37013646?location...
# 10  https://www.airbnb.com.ro/rooms/41489971?locat...
#
#                                                   url    guests   bedrooms  \
# Id
# 3   https://www.airbnb.com.ro/rooms/30854683?locat...  4 guests  2 bedroom
# 4   https://www.airbnb.com.ro/rooms/40392854?locat...  2 guests     studio
# 5   https://www.airbnb.com.ro/rooms/39247207?locat...  4 guests  1 bedroom
# 6   https://www.airbnb.com.ro/rooms/37375840?locat...  2 guests  2 bedroom
# 7   https://www.airbnb.com.ro/rooms/37008313?locat...  4 guests  1 bedroom
# ...

# %%
df.loc[3, ['reviews', 'price', 'stars']]
# Out:
# reviews      0
# price      121
# stars        0
# Name: 3, dtype: object

# %%
df.loc[[2, 3], ['reviews', 'price', 'stars']]
# Out:
#     reviews  price  stars
# Id
# 2         5  140.0    5.0
# 3         0  121.0    0.0

# %%
df.loc[2:6, ['reviews', 'price', 'stars']]
# Out:
#     reviews  price  stars
# Id
# 2         5  140.0   5.00
# 3         0  121.0   0.00
# 4        12  131.0   4.83
# 5        10  257.0   4.60
# 6         3  257.0   5.00

# %%
df.iloc[0]
# Out:
# listings     https://www.airbnb.com.ro/rooms/37103158?locat...
# url          https://www.airbnb.com.ro/rooms/37103158?locat...
# guests                                               10 guests
# bedrooms                                             1 bedroom
# bed                                                      1 bed
# bathrooms                                               1 bath
# room_type                         Shared room in the apartment
# price                                                       81
# host_name                                               George
# reviews                                                     18
# stars                                                     4.67
# location                                       Brasov, Romania
# latitude                                               4564293
# longitude                                              2559111
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# listings     https://www.airbnb.com.ro/rooms/36500195?locat...
# url          https://www.airbnb.com.ro/rooms/36500195?locat...
# guests                                                4 guests
# bedrooms                                             1 bedroom
# bed                                                     2 bath
# bathrooms                                               1 bath
# room_type                                          Entire home
# price                                                       99
# host_name                                              Gyongyi
# reviews                                                     30
# stars                                                     4.87
# location                                       Brasov, Romania
# latitude                                                456559
# longitude                                              2559361
# Name: 267, dtype: object

# %% [markdown]
# # Summary statistics

# %%
df.describe()
# Out:
#             price     reviews       stars      latitude     longitude
# count  268.000000  268.000000  258.000000  2.680000e+02  2.680000e+02
# mean   204.602127   24.037313    3.360581  7.048500e+06  5.085368e+06
# std     96.560204   44.664611    2.245887  3.917594e+07  2.686446e+07
# min      1.170000    0.000000    0.000000  0.000000e+00  0.000000e+00
# 25%    140.000000    1.000000    0.000000  4.561736e+06  2.555739e+06
# 50%    187.500000    9.000000    4.815000  4.564251e+06  2.559010e+06
# 75%    242.000000   28.000000    4.980000  4.565190e+06  2.560328e+06
# max    550.000000  367.000000    5.000000  4.566906e+08  2.561028e+08

# %%
df['price'].mean()
# Out:
# 204.60212686567164

# %%
df['price'].sum()
# Out:
# 54833.37

# %%
df['price'].max()
# Out:
# 550.0

# %%
df['price'].min()
# Out:
# 1.17

# %%
df['reviews'].mean()
# Out:
# 24.03731343283582

# %%
df['reviews'].sum()
# Out:
# 6442

# %%
df['reviews'].max()
# Out:
# 367

# %%
df['reviews'].min()
# Out:
# 0

# %%
df['stars'].mean()
# Out:
# 3.3605813953488366

# %%
df['stars'].sum()
# Out:
# 867.03

# %%
df['stars'].min()
# Out:
# 0.0

# %%
df['stars'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-34473ba0a5c7> in <module>
# ----> 1 df['stars'].max()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Column distribution analysis

# %%
rev = sns.distplot(df['reviews'], color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-89db65754adc> in <module>
# ----> 1 rev = sns.distplot(df['reviews'], color='red')
#       2
#
# NameError: name 'sns' is not defined

# %%
sns.distplot(df['price'], color='blue')

# %%
df= pd.DataFrame(range(5), columns=['stars'])
df.stars = df.stars.astype(int)

# %%
sns.distplot(df['stars'], color='green')

# %% [markdown]
# # Corellation between columns

# %%
p = df.reindex(columns=[ 'stars'])

# %%
df.columns = (df.columns.str.strip().str.upper()
              .str.replace(' ', '_')
              .str.replace('(', '')
              .str.replace(')', ''))

# %%
df.head()
# Out:
#    STARS
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
df.dtypes
# Out:
# STARS    int32
# dtype: object

# %%
df = pd.read_csv('airbnb_datesv2.csv', sep=';')
df.head()
# Out:
#                                             listings  \
# 0           "FUNTASTIC"Hostel in the Centre:   Stage
# 1  "ROOM 88" Unique Experience Location and Light...
# 2                   2   Spacious & Modern Apartament
# 3                                     4-5 apartament
# 4                                   5 Stars luxury 1
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...       4          2
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# ...

# %%
sns.lmplot(x='stars', y='reviews', data=df, height=7)

# %% [markdown]
# # Filtering/ Conditional Selection/ Boolean arrays

# %%
#Filtering / Conditional Selection / Boolean arrays

#Will allow you to select different elements from a DataFrame or Series.

df_small = df.loc[0:10]

df_small
# Out:
#                                              listings  \
# 0            "FUNTASTIC"Hostel in the Centre:   Stage
# 1   "ROOM 88" Unique Experience Location and Light...
# 2                    2   Spacious & Modern Apartament
# 3                                      4-5 apartament
# 4                                    5 Stars luxury 1
# 5                    92 Castelului - one   apartament
# 6        A night in the Museum of Living in Communism
# 7                       Ada Old Town Apartaments no 7
# 8                            Ada Old Town Apartment 3
# 9                        Ada Old Town Apartments no 6
# 10                                            Adriana
#
#                                                   url  guests   bedrooms  \
# 0   https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1   https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2   https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# ...

# %%
df_small[[True, True, True, True, True, True, True, True, True,True, True]]
# Out:
#                                              listings  \
# 0            "FUNTASTIC"Hostel in the Centre:   Stage
# 1   "ROOM 88" Unique Experience Location and Light...
# 2                    2   Spacious & Modern Apartament
# 3                                      4-5 apartament
# 4                                    5 Stars luxury 1
# 5                    92 Castelului - one   apartament
# 6        A night in the Museum of Living in Communism
# 7                       Ada Old Town Apartaments no 7
# 8                            Ada Old Town Apartment 3
# 9                        Ada Old Town Apartments no 6
# 10                                            Adriana
#
#                                                   url  guests   bedrooms  \
# 0   https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1   https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2   https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# ...

# %%
df_small[[True, False, False, True, False, False, True, False, False, True, False]]
# Out:
#                                        listings  \
# 0      "FUNTASTIC"Hostel in the Centre:   Stage
# 3                                4-5 apartament
# 6  A night in the Museum of Living in Communism
# 9                  Ada Old Town Apartments no 6
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...       4          2
# 6  https://www.airbnb.com.ro/rooms/37375840?locat...       2          2
# 9  https://www.airbnb.com/rooms/37013646?location...       3          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# 3      2           1                   Entire home  121.0      Nicu        0
# 6      2           1                   Entire home  257.0    Raluca        3
# ...

# %%
import sys
for longitude in sys.stdin:
        longitude = line.strip()
        latitude = line.split()

# %%
df.dtypes
# Out:
# listings       object
# url            object
# guests          int64
#  bedrooms       int64
#  beds           int64
#  bathrooms      int64
# room_type      object
# price         float64
# host_name      object
# reviews         int64
# stars         float64
# location       object
# latitude       object
# longitude      object
# dtype: object

# %% [markdown]
# # Combined operations

# %%
df_small.loc[(df_small['price'] > 5) & (df_small['reviews'] > 5)]
# Out:
#                                             listings  \
# 0           "FUNTASTIC"Hostel in the Centre:   Stage
# 1  "ROOM 88" Unique Experience Location and Light...
# 4                                   5 Stars luxury 1
# 5                   92 Castelului - one   apartament
# 7                      Ada Old Town Apartaments no 7
# 8                           Ada Old Town Apartment 3
# 9                       Ada Old Town Apartments no 6
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
# 5  https://www.airbnb.com.ro/rooms/39247207?locat...       4          1
# 7  https://www.airbnb.com.ro/rooms/37008313?locat...       4          1
# 8  https://www.airbnb.com.ro/rooms/37516728?locat...       4          1
# ...

# %%
(df_small['price'] >= 100) & (df_small['stars'] > 4.5)
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# dtype: bool

# %%
df_small.loc[(df_small['price'] >= 100) & (df_small['stars'] > 4.5)]
# Out:
#                                             listings  \
# 1  "ROOM 88" Unique Experience Location and Light...
# 2                   2   Spacious & Modern Apartament
# 4                                   5 Stars luxury 1
# 5                   92 Castelului - one   apartament
# 6       A night in the Museum of Living in Communism
# 7                      Ada Old Town Apartaments no 7
# 8                           Ada Old Town Apartment 3
# 9                       Ada Old Town Apartments no 6
#
#                                                  url  guests   bedrooms  \
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
# 5  https://www.airbnb.com.ro/rooms/39247207?locat...       4          1
# 6  https://www.airbnb.com.ro/rooms/37375840?locat...       2          2
# ...

# %% [markdown]
# # Summary statistics after selecting

# %%
df_small['price'] > 80
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# Name: price, dtype: bool

# %%
df_small.loc[df_small['reviews'] == 'George'].mean()
# Out:
# C:\Users\Ariana\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# listings     NaN
# url          NaN
# guests       NaN
#  bedrooms    NaN
#  beds        NaN
#  bathrooms   NaN
# room_type    NaN
# price        NaN
# host_name    NaN
# reviews      NaN
# stars        NaN
# location     NaN
# latitude     NaN
# longitude    NaN
# dtype: float64

# %%
df.loc[df['reviews']]
# Out:
# C:\Users\Ariana\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                                              listings  \
# 18               Apartament nou, curat si confortabil
# 34                         Bellevue Apartament Brasov
# 5                    92 Castelului - one   apartament
# 0            "FUNTASTIC"Hostel in the Centre:   Stage
# 12                                   Alexandra's Home
# ..                                                ...
# 1   "ROOM 88" Unique Experience Location and Light...
# 28           Balcescu Apartament in Historical Center
# 5                    92 Castelului - one   apartament
# ...

# %%
total_count = df.shape[0]
reviews_count = df.loc[df['reviews']].shape[0]
no_reviews_count = total_count - reviews_count
# Out:
# C:\Users\Ariana\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
plt.pie([no_reviews_count, reviews_count],
        labels=['Not reviews', 'reviews'],
        autopct='%1.1f%%',
        shadow=True,
        startangle=90,
        explode=(0, 0.1))

plt.title('reviews', fontsize=12)

plt.show()
plt.savefig("output.png")

# %%
total_count = df.shape[0]
price_count = df.loc[df['price']].shape[0]
stars_count = df.loc[df['stars']].shape[1]
# Out:
# C:\Users\Ariana\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#
# C:\Users\Ariana\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.pie([stars_count, price_count],
        labels=['stars', 'price'],
        autopct='%1.0f%%',
        shadow=True,
        startangle=90,
        explode=(0, 0.1))

plt.title('Statistics', fontsize=12)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

ax1.tick_params(axis='x', rotation=45)
ax2.tick_params(axis='x', rotation=45)

sns.countplot(x='guests', data=df, ax=ax1)

sns.countplot(x='room_type', data=df, ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(50, 30))

ax1.tick_params(axis='x', rotation=60)
ax2.tick_params(axis='x', rotation=45)

sns.countplot(x='reviews', data=df, ax=ax1)

sns.countplot(x='room_type', data=df, ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

ax1.tick_params(axis='x', rotation=60)
ax2.tick_params(axis='x', rotation=45)

sns.countplot(x='bathrooms', data=df, ax=ax1)

sns.countplot(x='room_type', data=df, ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-cc31c327925a> in <module>
#       4 ax2.tick_params(axis='x', rotation=45)
#       5
# ----> 6 sns.countplot(x='bathrooms', data=df, ax=ax1)
#       7
#       8 sns.countplot(x='room_type', data=df, ax=ax2)
#
# C:\Users\Ariana\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ...

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

ax1.tick_params(axis='x', rotation=60)
ax2.tick_params(axis='x', rotation=45)

sns.countplot(x='bedrooms', data=df, ax=ax1)

sns.countplot(x='bed', data=df, ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

ax1.tick_params(axis='x', rotation=60)
ax2.tick_params(axis='x', rotation=45)

sns.countplot(x='room_type', data=df, ax=ax1)

sns.countplot(x='bed', data=df, ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-3c3ea8676657> in <module>
#       6 sns.countplot(x='room_type', data=df, ax=ax1)
#       7
# ----> 8 sns.countplot(x='bed', data=df, ax=ax2)
#
# C:\Users\Ariana\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# C:\Users\Ariana\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %% [markdown]
# # Data Cleaning with Pandas

# %% [markdown]
# #### Total Calculated=guests+price+reviews+stars

# %%
df['Total Calculated'] = df[['guests', 'price', 'reviews', 'stars']].sum(axis=1)

df.head()
# Out:
#                                             listings  \
# 0           "FUNTASTIC"Hostel in the Centre:   Stage
# 1  "ROOM 88" Unique Experience Location and Light...
# 2                   2   Spacious & Modern Apartament
# 3                                     4-5 apartament
# 4                                   5 Stars luxury 1
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...       4          2
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# ...

# %%
df['Total Calculated'].plot.hist()

# %%
sns.distplot(df['Total Calculated'])

# %% [markdown]
# #  Outliers detection

# %%
#df['Total'].plot.box()
sns.boxplot(y=c, data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-f6485951b21f> in <module>
#       1 #df['Total'].plot.box()
# ----> 2 sns.boxplot(y=c, data=df)
#       3
#
# NameError: name 'c' is not defined

# %%
sns.boxplot(x='room_type', y='Total Calculated', data=df)

# %% [markdown]
# # Removing rows and columns

# %%
df.drop([1, 2, 3]).head()
# Out:
#                                        listings  \
# 0      "FUNTASTIC"Hostel in the Centre:   Stage
# 4                              5 Stars luxury 1
# 5              92 Castelului - one   apartament
# 6  A night in the Museum of Living in Communism
# 7                 Ada Old Town Apartaments no 7
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
# 5  https://www.airbnb.com.ro/rooms/39247207?locat...       4          1
# 6  https://www.airbnb.com.ro/rooms/37375840?locat...       2          2
# 7  https://www.airbnb.com.ro/rooms/37008313?locat...       4          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# 4      1           1                   Entire home  131.0    Marius       12
# ...

# %%
df.drop(['longitude', 'latitude'], axis=1).head()
# Out:
#                                             listings  \
# 0           "FUNTASTIC"Hostel in the Centre:   Stage
# 1  "ROOM 88" Unique Experience Location and Light...
# 2                   2   Spacious & Modern Apartament
# 3                                     4-5 apartament
# 4                                   5 Stars luxury 1
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...       4          2
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# ...

# %% [markdown]
# # Sorting values

# %%
df.sort_values(by='price').head()
# Out:
#                                        listings  \
# 178                 Much better than in picture
# 244                        Transilvania Mansion
# 105  Five minutes to downtown Arthur Apartament
# 120                 Hostel Boemia 8 shared dorm
# 12                             Alexandra's Home
#
#                                                    url  guests   bedrooms  \
# 178  https://www.airbnb.com.ro/rooms/3098344?locati...      14          4
# 244  https://www.airbnb.com.ro/rooms/41209956?locat...      16          8
# 105  https://www.airbnb.com.ro/rooms/43233781?locat...       2          1
# 120  https://www.airbnb.com.ro/rooms/3982720?locati...       8          1
# 12   https://www.airbnb.com.ro/rooms/34451161?locat...       2          1
#
#       beds   bathrooms                     room_type  price host_name  \
# 178      7           3                   Entire home   1.17    Andrei
# 244     11           8                   Entire home   2.20   Antonia
# ...

# %%
df.sort_values(by='stars', ascending=False).head()
# Out:
#                                          listings  \
# 131                    IQ Apart 5B - Brasov West
# 188                      Panoramic Center Apt. BV
# 84              Cozy flat in the heart of Brasov
# 80   Cozy A&R Homes-Full Apartmane Brasov,Romania
# 77                                    Confort Ale
#
#                                                    url  guests   bedrooms  \
# 131  https://www.airbnb.com.ro/rooms/32354316?locat...       2          1
# 188  https://www.airbnb.com.ro/rooms/38797004?locat...       4          1
# 84   https://www.airbnb.com.ro/rooms/40361314?locat...       4          1
# 80   https://www.airbnb.com.ro/rooms/38821577?locat...       6          2
# 77   https://www.airbnb.com.ro/rooms/40001059?locat...       2          1
#
#       beds   bathrooms    room_type  price host_name  reviews  stars  \
# 131      1           1  Entire home  220.0        Iq        8    5.0
# 188      2           1  Entire home  188.0       Ben        3    5.0
# ...

# %% [markdown]
# # Grouping and Aggregations

# %%
dff=pd.read_csv('airbnb_datesv2.csv', sep=';')
dff.head()
# Out:
#                                             listings  \
# 0           "FUNTASTIC"Hostel in the Centre:   Stage
# 1  "ROOM 88" Unique Experience Location and Light...
# 2                   2   Spacious & Modern Apartament
# 3                                     4-5 apartament
# 4                                   5 Stars luxury 1
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...       4          2
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 10))

sns.lineplot(data=formatted_df,
             dashes=False,
             ax=ax)

plt.legend(loc='center right', bbox_to_anchor=(1.1, 0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-60978103da93> in <module>
#       1 fig, ax = plt.subplots(figsize=(16, 10))
#       2
# ----> 3 sns.lineplot(data=formatted_df,
#       4              dashes=False,
#       5              ax=ax)
#
# NameError: name 'formatted_df' is not defined

# %%
dff.dtypes
# Out:
# listings       object
# url            object
# guests          int64
#  bedrooms       int64
#  beds           int64
#  bathrooms      int64
# room_type      object
# price         float64
# host_name      object
# reviews         int64
# stars         float64
# location       object
# latitude       object
# longitude      object
# dtype: object

# %%
room = dff.groupby('guests')

room_type = room['reviews'].mean().sort_values(ascending=False)

room_type
# Out:
# guests
# 6     63.761905
# 8     30.833333
# 7     30.666667
# 5     28.416667
# 14    25.000000
# 2     22.538462
# 4     19.720000
# 3     15.230769
# 10     9.000000
# 1      5.250000
# 16     1.000000
# Name: reviews, dtype: float64

# %%
sns.barplot(x=room_type.index,
            y=room_type,
            order=room_type.index)

# %%
generations_type = dff.groupby(['beds', 'bedrooms'])

generations_type_a = generations_type['room_type'].mean()

generations_type_a.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-197a88ac0112> in <module>
# ----> 1 generations_type = dff.groupby(['beds', 'bedrooms'])
#       2
#       3 generations_type_a = generations_type['room_type'].mean()
#       4
#       5 generations_type_a.head(20)
#
# C:\Users\Ariana\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# C:\Users\Ariana\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ...

# %%
formatted_df = generations_type_a.unstack()

formatted_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-b4ed1928277e> in <module>
# ----> 1 formatted_df = generations_type_a.unstack()
#       2
#       3 formatted_df.head(10)
#
# NameError: name 'generations_type_a' is not defined

# %%
import pandas as pd
pattern = '*.centre'
print (len(pattern))
print(csv_files)
csv2 = pd.read_csv("airbnb_datesv2.csv", sep=';')
print(csv2.head())
# Out:
# 8
# []
#                                             listings  \
# 0           "FUNTASTIC"Hostel in the Centre:   Stage
# 1  "ROOM 88" Unique Experience Location and Light...
# 2                   2   Spacious & Modern Apartament
# 3                                     4-5 apartament
# 4                                   5 Stars luxury 1
#
#                                                  url  guests   bedrooms  \
# 0  https://www.airbnb.com.ro/rooms/37103158?locat...      10          1
# 1  https://www.airbnb.com.ro/rooms/39272931?locat...       4          1
# 2  https://www.airbnb.com.ro/rooms/39502159?locat...       4          2
# 3  https://www.airbnb.com.ro/rooms/30854683?locat...       4          2
# 4  https://www.airbnb.com.ro/rooms/40392854?locat...       2          1
#
#     beds   bathrooms                     room_type  price host_name  reviews  \
# 0      1           1  Shared room in the apartment   81.0    George       18
# ...

# %%
import pandas as pd
# Scriere pattern
csv2 = pd.read_csv("airbnb_datesv2.csv", sep=';')
pattern = '*centru'
print(len(pattern))
# Out:
# 7
